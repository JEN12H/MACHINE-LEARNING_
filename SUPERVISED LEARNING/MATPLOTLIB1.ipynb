# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
blood_sugar_men = [113,85,90,150,149,88,93,115,135,80,77,82,129]
blood_sugar_women = [ 67,98,89,120,133,150,84,69,89,79,129,112,100]
plt.xlabel('sugar range')
plt.ylabel('total number of patients')
plt.title('blood sugar analysis')
plt.hist([blood_sugar_men,blood_sugar_women],bins=[80,100,125,200],rwidth=0.80,color =['green','orange'],label=['men','women'])
plt.legend()
