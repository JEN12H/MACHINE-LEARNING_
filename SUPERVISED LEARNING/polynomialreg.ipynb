# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn import pipeline

# %%
X = 6* np.random.rand(200,1) -3
y = 0.8*X **2 + 0.9*X +2+np.random.randn(200,1)
# y = 0.8X^2 + 0.9X + 2

# %%
plt.plot(X_train,lr.predict(X_train),color='g') # lr.predict(X_train) is used so that the prediction array will be of same size as that of X_train
plt.plot(X,y,'b.')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# train test split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 2)

# %%
# applying Linear regression 
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# make prediction using test data
y_pred = lr.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.48529608500669863

# %%
# USING POLYNOMIAL LINEAR REGRESSION
poly = PolynomialFeatures(degree =2,include_bias = True)
X_train_trans = poly.fit_transform(X_train)
X_test_trans = poly.transform(X_test)

# %%
print(X_train[0])
print(X_train_trans[0])
# we only apply polynomial features on input not on output .and is applied  on both train and test data of input
# Out:
# [2.11430414]
# [1.         2.11430414 4.470282  ]

# %%
lr= LinearRegression()
lr.fit(X_train_trans,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test_trans)
r2_score(y_test,y_pred)
# Out:
# 0.8491772565393465

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[0.         0.87515778 0.79916034]]
# [2.04790478]

# %%
X_new = np.linspace(-3,3,200).reshape(200,1)
X_new_poly = poly.transform(X_new)
y_new = lr.predict(X_new_poly)

# %%
plt.plot(X_new,y_new,"r-",linewidth=2,label ="predictions")
plt.plot(X_train,y_train,"b.",label="TRAINING POINTS")
plt.plot(X_test,y_test,"g.",label="TESTING POINTS")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()
