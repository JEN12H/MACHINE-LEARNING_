# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_vals =[1600,620,300,410,250]
exp_labels =["home rent","Food","Internet/Bill","car","utilities"]

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels,radius=2,autopct ='%0.0f%%',shadow=True,explode=[0,1,0,0,0],startangle=90)
plt.show()
